# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread("../data/benchmarks/lion.png", cv2.IMREAD_UNCHANGED)
img.shape
# Out:
# (1920, 1920, 4)

# %%
img_bgr = img[..., 0:3]            # Use only three channels - blue, green , red
img_with_alpha = img[..., -1]      # Get only last channel - alpha
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img_rgb)
plt.title("Original RGB image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img_with_alpha, cmap='gray')
plt.title("Alpha (Transparency) Channel")
plt.axis('off')

plt.show()

# %%
square = np.zeros((300, 300), np.uint8)              # Creating canvas
cv2.rectangle(square, (50, 50), (250, 250), 255,-1)  # 50, 250 coordinates, 255 color, -1 fill with that color

ellipse = np.zeros((300, 300), np.uint8)
cv2.ellipse(ellipse, (150, 150), (150, 150), 30, 0, 180, 255, -1)

plt.subplot(121);plt.imshow(square,cmap='gray');plt.title("square");
plt.subplot(122);plt.imshow(ellipse,cmap='gray');plt.title("ellipse");

# %%
# Shows only where they intersect
bitwise_and = cv2.bitwise_and(square, ellipse)

# Shows where either square or ellipse is
bitwise_or = cv2.bitwise_or(square, ellipse)

# Shows where either exist by itself
bitwise_xor = cv2.bitwise_xor(square, ellipse)

# Shows everything that isn't part of the square
bitwise_not_sq = cv2.bitwise_not(square)

#show
plt.figure(figsize=[12,6])
plt.subplot(245);plt.imshow(bitwise_and,cmap='gray');plt.title("And");
plt.subplot(246);plt.imshow(bitwise_or,cmap='gray');plt.title("Or");
plt.subplot(247);plt.imshow(bitwise_xor,cmap='gray');plt.title("Xor");
plt.subplot(248);plt.imshow(bitwise_not_sq,cmap='gray');plt.title("not (square)");

# %%
img_1 = cv2.imread("../data/benchmarks/camera.png")
cropped = img_1[100:600 , 150:650]

h, w, c = cropped.shape

mask = np.zeros((h, w, c), np.uint8)
cv2.circle(mask, (w//2, h//2), min(w, h)//2, (255, 255, 255), -1)

output_img = cv2.bitwise_and(cropped, mask)
plt.imshow(output_img[...,::-1])

# %%
image = np.zeros((512, 512, 3), np.uint8)             # 3D black image
# (512, 512, 3): height × width × 3 color channels (BGR)
# np.uint8: 8-bit unsigned integer type (pixel values 0–255)

image_bw = np.zeros((512, 512), np.uint8)             # 2D Grayscale image
# Only 2D because grascale has a single channel

plt.subplot(1, 2, 1)
plt.imshow(image[...,::-1])                           # Converting BGR to RGB for matplotlib
plt.title("Generated black image")

plt.subplot(1, 2, 2)
plt.imshow(image_bw, cmap='gray')
plt.title("Black and White image")
# Out:
# Text(0.5, 1.0, 'Black and White image')

# %%
image = np.zeros((512, 512, 3), np.uint8)

cv2.line(image, (0, 0), (511, 511), (255, 127, 0), 5)

plt.imshow(image[..., ::-1])
plt.title("Diagonal line")
plt.show()

# %%
image = np.zeros((512, 512, 3), np.uint8)

cv2.rectangle(image, (100, 100), (300, 250), (0, 0, 255), 5)
cv2.rectangle(image, (300, 300), (500, 400), (255, 0, 0), 5)

plt.imshow(image[..., ::-1])
plt.title("Rectangles")
plt.show()

# %%
img = cv2.cvtColor(cv2.imread("../data/benchmarks/coffee.png"), cv2.COLOR_BGR2RGB) 

cv2.rectangle(img, (200, 65), (400, 170), (0, 255, 0), 5)

plt.imshow(img)
plt.title("Rectangle on the coffee")
# Out:
# Text(0.5, 1.0, 'Rectangle on the coffee')

# %%
image = np.zeros((512, 512, 3), np.uint8)

cv2.circle(image, (350, 350), 100, (15, 75, 50), 7)

plt.imshow(image[..., ::-1])
plt.title("Circle")
plt.show()

# %%
ellipse = np.zeros((512, 512, 3), np.uint8)
cv2.ellipse(ellipse, (250, 250), (250, 100), 45, 90, 360, (255, 255, 255), -1)

polygon = np.zeros((512, 512, 3), np.uint8)
pts = np.array([[10, 50], [400, 50], [90, 200], [50, 500]], np.int32)
pts = pts.reshape((-1, 1, 2))
cv2.polylines(polygon, [pts], True, (0, 0, 255), 3)

plt.subplot(1, 2, 1)
plt.imshow(ellipse[..., ::-1])
plt.title("Ellipse")
plt.show()

plt.subplot(1, 2, 2)
plt.imshow(image[..., ::-1])
plt.title("Polygon")
plt.show()

# %%
image = np.zeros((512, 512, 3), np.uint8)

cv2.putText(image, 'DIP is cool!', (75, 290), cv2.FONT_HERSHEY_COMPLEX, 2, (100, 170, 0), 3)

plt.imshow(image[..., ::-1])
plt.title("Hello World!")
plt.show()
